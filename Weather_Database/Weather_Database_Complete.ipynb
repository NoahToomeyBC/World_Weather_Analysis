# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# use api call to create weather url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 796

# %%
# use api call to create weather url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        ds = city_weather["weather"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather": ds[0]['description']
                           })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | krasnogorsk
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | vimperk
# Processing Record 12 of Set 1 | rocha
# Processing Record 13 of Set 1 | lagos
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | bure
# Processing Record 20 of Set 1 | egvekinot
# Processing Record 21 of Set 1 | verkhnyaya inta
# Processing Record 22 of Set 1 | kesennuma
# City not found. Skipping...
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | berlevag
# Processing Record 26 of Set 1 | sri aman
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | flinders
# Processing Record 29 of Set 1 | kiama
# Processing Record 30 of Set 1 | darab
# Processing Record 31 of Set 1 | pitkyaranta
# Processing Record 32 of Set 1 | ibadan
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | yumen
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | meulaboh
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | sangar
# Processing Record 41 of Set 1 | shimoda
# Processing Record 42 of Set 1 | nova vicosa
# Processing Record 43 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | thohoyandou
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | vila franca do campo
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | north platte
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | chernyshevskiy
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | columbus
# Processing Record 7 of Set 2 | adrar
# Processing Record 8 of Set 2 | quatre cocos
# Processing Record 9 of Set 2 | namatanai
# Processing Record 10 of Set 2 | irshava
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | henties bay
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | thinadhoo
# Processing Record 16 of Set 2 | namangan
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | takaka
# Processing Record 19 of Set 2 | eau claire
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | havre-saint-pierre
# Processing Record 22 of Set 2 | coroata
# Processing Record 23 of Set 2 | nhulunbuy
# Processing Record 24 of Set 2 | severodvinsk
# Processing Record 25 of Set 2 | banovici
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | narsaq
# Processing Record 29 of Set 2 | nishihara
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | jumla
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | tual
# Processing Record 34 of Set 2 | atar
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | khorixas
# Processing Record 40 of Set 2 | port-cartier
# Processing Record 41 of Set 2 | elizabeth city
# Processing Record 42 of Set 2 | pemberton
# Processing Record 43 of Set 2 | zalesovo
# Processing Record 44 of Set 2 | los llanos de aridane
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 3 | nabire
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | tabou
# Processing Record 6 of Set 3 | luganville
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | naze
# Processing Record 10 of Set 3 | belyy yar
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | labuhan
# Processing Record 14 of Set 3 | xinyu
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | roshchino
# Processing Record 17 of Set 3 | pacific grove
# Processing Record 18 of Set 3 | arlit
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | richmond
# Processing Record 21 of Set 3 | ketchikan
# Processing Record 22 of Set 3 | bengkulu
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | kundiawa
# Processing Record 26 of Set 3 | bluefields
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | boras
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | isangel
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | la maddalena
# Processing Record 34 of Set 3 | tarakan
# Processing Record 35 of Set 3 | sur
# Processing Record 36 of Set 3 | lebu
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | marsh harbour
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | dhidhdhoo
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | poplar bluff
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | gambela
# Processing Record 47 of Set 3 | qabis
# City not found. Skipping...
# Processing Record 48 of Set 3 | tuatapere
# Processing Record 49 of Set 3 | sol-iletsk
# Processing Record 50 of Set 3 | alyangula
# Processing Record 1 of Set 4 | monreal
# Processing Record 2 of Set 4 | ocos
# Processing Record 3 of Set 4 | srednekolymsk
# Processing Record 4 of Set 4 | khandyga
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | kiunga
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | vredendal
# Processing Record 9 of Set 4 | hambantota
# Processing Record 10 of Set 4 | alice
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | pingshan
# Processing Record 13 of Set 4 | shingu
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | tiznit
# Processing Record 17 of Set 4 | karratha
# Processing Record 18 of Set 4 | kentau
# Processing Record 19 of Set 4 | porto novo
# Processing Record 20 of Set 4 | mareeba
# Processing Record 21 of Set 4 | mariana
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | kurchum
# Processing Record 24 of Set 4 | podor
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | linhai
# Processing Record 27 of Set 4 | chara
# Processing Record 28 of Set 4 | aldan
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | killybegs
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | puerto madero
# Processing Record 33 of Set 4 | chesapeake
# Processing Record 34 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 4 | comodoro rivadavia
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | san jose
# Processing Record 38 of Set 4 | butaritari
# Processing Record 39 of Set 4 | kilindoni
# Processing Record 40 of Set 4 | kidal
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | sorland
# Processing Record 44 of Set 4 | praia da vitoria
# Processing Record 45 of Set 4 | anori
# Processing Record 46 of Set 4 | leningradskiy
# Processing Record 47 of Set 4 | quelimane
# Processing Record 48 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 4 | fort nelson
# Processing Record 50 of Set 4 | pampa
# Processing Record 1 of Set 5 | ekibastuz
# Processing Record 2 of Set 5 | nantucket
# Processing Record 3 of Set 5 | rio grande
# Processing Record 4 of Set 5 | markova
# Processing Record 5 of Set 5 | talcahuano
# Processing Record 6 of Set 5 | paita
# Processing Record 7 of Set 5 | barcelos
# Processing Record 8 of Set 5 | chapais
# Processing Record 9 of Set 5 | esso
# Processing Record 10 of Set 5 | blagoyevo
# Processing Record 11 of Set 5 | lubango
# Processing Record 12 of Set 5 | howard springs
# Processing Record 13 of Set 5 | la crosse
# Processing Record 14 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 5 | ilsede
# Processing Record 16 of Set 5 | hastings
# Processing Record 17 of Set 5 | hualmay
# Processing Record 18 of Set 5 | ola
# Processing Record 19 of Set 5 | saint-joseph
# Processing Record 20 of Set 5 | campobasso
# Processing Record 21 of Set 5 | zhigansk
# Processing Record 22 of Set 5 | ipaba
# Processing Record 23 of Set 5 | itarema
# Processing Record 24 of Set 5 | pitimbu
# Processing Record 25 of Set 5 | esperance
# Processing Record 26 of Set 5 | vasudevanallur
# Processing Record 27 of Set 5 | sao jose da coroa grande
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | mochishche
# Processing Record 33 of Set 5 | marawi
# Processing Record 34 of Set 5 | tautira
# Processing Record 35 of Set 5 | owando
# Processing Record 36 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | topolobampo
# Processing Record 39 of Set 5 | dikson
# Processing Record 40 of Set 5 | huntly
# Processing Record 41 of Set 5 | kourou
# Processing Record 42 of Set 5 | malartic
# Processing Record 43 of Set 5 | komsomolskiy
# Processing Record 44 of Set 5 | kushiro
# Processing Record 45 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 5 | llanes
# Processing Record 47 of Set 5 | lhokseumawe
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 50 of Set 5 | saquena
# Processing Record 1 of Set 6 | halifax
# Processing Record 2 of Set 6 | byron bay
# Processing Record 3 of Set 6 | meiganga
# Processing Record 4 of Set 6 | tiarei
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | lebanon
# Processing Record 7 of Set 6 | romanovka
# Processing Record 8 of Set 6 | antsohihy
# Processing Record 9 of Set 6 | barrow
# Processing Record 10 of Set 6 | sibolga
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | fandriana
# Processing Record 13 of Set 6 | grebanu
# Processing Record 14 of Set 6 | bundaberg
# Processing Record 15 of Set 6 | kaspiysk
# Processing Record 16 of Set 6 | ballina
# Processing Record 17 of Set 6 | sergeyevka
# Processing Record 18 of Set 6 | hirara
# Processing Record 19 of Set 6 | acari
# Processing Record 20 of Set 6 | birchis
# Processing Record 21 of Set 6 | morehead
# Processing Record 22 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 6 | siutu
# City not found. Skipping...
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 6 | alexandria
# Processing Record 28 of Set 6 | makakilo city
# Processing Record 29 of Set 6 | aktash
# Processing Record 30 of Set 6 | arrifes
# Processing Record 31 of Set 6 | lensk
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | samarai
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | lavrentiya
# Processing Record 36 of Set 6 | beloha
# Processing Record 37 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | kingman
# Processing Record 40 of Set 6 | ferrol
# Processing Record 41 of Set 6 | pabna
# Processing Record 42 of Set 6 | sao joao da barra
# Processing Record 43 of Set 6 | poum
# Processing Record 44 of Set 6 | blairmore
# Processing Record 45 of Set 6 | araouane
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | bilibino
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | aklavik
# Processing Record 50 of Set 6 | tianmen
# Processing Record 1 of Set 7 | itzehoe
# Processing Record 2 of Set 7 | solnechnyy
# Processing Record 3 of Set 7 | najran
# Processing Record 4 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 7 | puerto colombia
# Processing Record 6 of Set 7 | portland
# Processing Record 7 of Set 7 | palembang
# Processing Record 8 of Set 7 | korla
# Processing Record 9 of Set 7 | noumea
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | qinhuangdao
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | lake station
# Processing Record 14 of Set 7 | faanui
# Processing Record 15 of Set 7 | anatoli
# Processing Record 16 of Set 7 | dawlatabad
# Processing Record 17 of Set 7 | vitim
# Processing Record 18 of Set 7 | hudiksvall
# Processing Record 19 of Set 7 | steinbach
# Processing Record 20 of Set 7 | kalomo
# City not found. Skipping...
# Processing Record 21 of Set 7 | sechura
# Processing Record 22 of Set 7 | dingle
# Processing Record 23 of Set 7 | mitu
# Processing Record 24 of Set 7 | inhambane
# Processing Record 25 of Set 7 | alofi
# Processing Record 26 of Set 7 | revda
# Processing Record 27 of Set 7 | acapulco
# Processing Record 28 of Set 7 | labrea
# Processing Record 29 of Set 7 | boyolangu
# Processing Record 30 of Set 7 | juneau
# Processing Record 31 of Set 7 | bafoulabe
# Processing Record 32 of Set 7 | provideniya
# Processing Record 33 of Set 7 | neuquen
# Processing Record 34 of Set 7 | bonthe
# Processing Record 35 of Set 7 | touros
# Processing Record 36 of Set 7 | uusikaupunki
# Processing Record 37 of Set 7 | aksu
# Processing Record 38 of Set 7 | puerto madryn
# Processing Record 39 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 40 of Set 7 | vestmannaeyjar
# Processing Record 41 of Set 7 | springfield
# Processing Record 42 of Set 7 | bukachacha
# Processing Record 43 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | alvaraes
# Processing Record 45 of Set 7 | zomin
# Processing Record 46 of Set 7 | sao luiz gonzaga
# Processing Record 47 of Set 7 | popondetta
# Processing Record 48 of Set 7 | port said
# Processing Record 49 of Set 7 | nouadhibou
# Processing Record 50 of Set 7 | laguna
# Processing Record 1 of Set 8 | kieta
# Processing Record 2 of Set 8 | great falls
# Processing Record 3 of Set 8 | constitucion
# Processing Record 4 of Set 8 | oyama
# Processing Record 5 of Set 8 | golden
# Processing Record 6 of Set 8 | bambey
# Processing Record 7 of Set 8 | altus
# Processing Record 8 of Set 8 | sola
# Processing Record 9 of Set 8 | avarua
# Processing Record 10 of Set 8 | aykhal
# Processing Record 11 of Set 8 | anyang
# Processing Record 12 of Set 8 | zacatepec
# Processing Record 13 of Set 8 | tazovskiy
# Processing Record 14 of Set 8 | surt
# Processing Record 15 of Set 8 | korgen
# Processing Record 16 of Set 8 | bowen
# Processing Record 17 of Set 8 | amuntai
# Processing Record 18 of Set 8 | binga
# Processing Record 19 of Set 8 | prainha
# Processing Record 20 of Set 8 | ahipara
# Processing Record 21 of Set 8 | mirador
# Processing Record 22 of Set 8 | vieux fort
# Processing Record 23 of Set 8 | nouakchott
# Processing Record 24 of Set 8 | lesnoy
# Processing Record 25 of Set 8 | agadez
# Processing Record 26 of Set 8 | chai badan
# Processing Record 27 of Set 8 | muzhi
# Processing Record 28 of Set 8 | ca mau
# Processing Record 29 of Set 8 | urengoy
# Processing Record 30 of Set 8 | baruun-urt
# Processing Record 31 of Set 8 | sakakah
# Processing Record 32 of Set 8 | norman wells
# Processing Record 33 of Set 8 | kousseri
# Processing Record 34 of Set 8 | garowe
# Processing Record 35 of Set 8 | sartana
# Processing Record 36 of Set 8 | saint-junien
# Processing Record 37 of Set 8 | lanxi
# Processing Record 38 of Set 8 | kigoma
# Processing Record 39 of Set 8 | caravelas
# Processing Record 40 of Set 8 | hasaki
# Processing Record 41 of Set 8 | grand-lahou
# Processing Record 42 of Set 8 | sarti
# Processing Record 43 of Set 8 | huilong
# Processing Record 44 of Set 8 | chokwe
# Processing Record 45 of Set 8 | vangaindrano
# Processing Record 46 of Set 8 | cariamanga
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | codrington
# Processing Record 49 of Set 8 | ankazobe
# Processing Record 50 of Set 8 | hobyo
# Processing Record 1 of Set 9 | saint marys
# Processing Record 2 of Set 9 | port moresby
# Processing Record 3 of Set 9 | nushki
# Processing Record 4 of Set 9 | yima
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | okhotsk
# Processing Record 7 of Set 9 | beberibe
# Processing Record 8 of Set 9 | zhangye
# Processing Record 9 of Set 9 | rancho palos verdes
# Processing Record 10 of Set 9 | cine
# Processing Record 11 of Set 9 | chifeng
# Processing Record 12 of Set 9 | talnakh
# Processing Record 13 of Set 9 | khani
# Processing Record 14 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 9 | saint anthony
# Processing Record 16 of Set 9 | husavik
# Processing Record 17 of Set 9 | dakar
# Processing Record 18 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 9 | natal
# Processing Record 20 of Set 9 | bandarbeyla
# Processing Record 21 of Set 9 | camacha
# Processing Record 22 of Set 9 | ambon
# Processing Record 23 of Set 9 | dudinka
# Processing Record 24 of Set 9 | palmer
# Processing Record 25 of Set 9 | adre
# Processing Record 26 of Set 9 | pechenizhyn
# Processing Record 27 of Set 9 | avera
# Processing Record 28 of Set 9 | whitehorse
# Processing Record 29 of Set 9 | pushkino
# Processing Record 30 of Set 9 | coahuayana
# Processing Record 31 of Set 9 | san patricio
# Processing Record 32 of Set 9 | darhan
# Processing Record 33 of Set 9 | juba
# Processing Record 34 of Set 9 | batagay
# Processing Record 35 of Set 9 | biskamzha
# Processing Record 36 of Set 9 | pointe michel
# Processing Record 37 of Set 9 | kalanwali
# Processing Record 38 of Set 9 | bilma
# Processing Record 39 of Set 9 | butembo
# Processing Record 40 of Set 9 | mackenzie
# Processing Record 41 of Set 9 | richards bay
# Processing Record 42 of Set 9 | hanyang
# Processing Record 43 of Set 9 | gilgit
# Processing Record 44 of Set 9 | lata
# Processing Record 45 of Set 9 | sant feliu de guixols
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | wieliczka
# Processing Record 48 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 9 | necochea
# Processing Record 50 of Set 9 | acarau
# Processing Record 1 of Set 10 | nanortalik
# Processing Record 2 of Set 10 | santa fe
# Processing Record 3 of Set 10 | presidencia roque saenz pena
# Processing Record 4 of Set 10 | dekar
# Processing Record 5 of Set 10 | majene
# Processing Record 6 of Set 10 | marrakesh
# Processing Record 7 of Set 10 | kamakwie
# Processing Record 8 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 10 of Set 10 | bogashevo
# Processing Record 11 of Set 10 | marovoay
# Processing Record 12 of Set 10 | saint-pierre
# Processing Record 13 of Set 10 | buchanan
# Processing Record 14 of Set 10 | black diamond
# Processing Record 15 of Set 10 | kargasok
# Processing Record 16 of Set 10 | lorengau
# Processing Record 17 of Set 10 | padang
# Processing Record 18 of Set 10 | sfantu gheorghe
# Processing Record 19 of Set 10 | cabo san lucas
# Processing Record 20 of Set 10 | alcantara
# Processing Record 21 of Set 10 | eydhafushi
# Processing Record 22 of Set 10 | chipinge
# Processing Record 23 of Set 10 | nata
# Processing Record 24 of Set 10 | calama
# Processing Record 25 of Set 10 | roma
# Processing Record 26 of Set 10 | marquette
# Processing Record 27 of Set 10 | ballachulish
# Processing Record 28 of Set 10 | finschhafen
# Processing Record 29 of Set 10 | colares
# Processing Record 30 of Set 10 | kamareddi
# Processing Record 31 of Set 10 | rongcheng
# Processing Record 32 of Set 10 | finote selam
# Processing Record 33 of Set 10 | yangjiang
# Processing Record 34 of Set 10 | prokhorovka
# Processing Record 35 of Set 10 | cabedelo
# Processing Record 36 of Set 10 | port augusta
# Processing Record 37 of Set 10 | warrnambool
# Processing Record 38 of Set 10 | cam ranh
# Processing Record 39 of Set 10 | lewiston
# Processing Record 40 of Set 10 | pontianak
# Processing Record 41 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 42 of Set 10 | te anau
# Processing Record 43 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 44 of Set 10 | marana
# Processing Record 45 of Set 10 | mangrol
# Processing Record 46 of Set 10 | ozinki
# Processing Record 47 of Set 10 | kupang
# Processing Record 48 of Set 10 | solvychegodsk
# Processing Record 49 of Set 10 | kyshtovka
# Processing Record 50 of Set 10 | chumikan
# Processing Record 1 of Set 11 | tianpeng
# Processing Record 2 of Set 11 | rudbar
# Processing Record 3 of Set 11 | la ligua
# Processing Record 4 of Set 11 | kawalu
# Processing Record 5 of Set 11 | vostok
# Processing Record 6 of Set 11 | ujhani
# Processing Record 7 of Set 11 | tromso
# Processing Record 8 of Set 11 | severo-kurilsk
# Processing Record 9 of Set 11 | yara
# Processing Record 10 of Set 11 | awbari
# Processing Record 11 of Set 11 | chitose
# Processing Record 12 of Set 11 | gurlan
# Processing Record 13 of Set 11 | riachao
# Processing Record 14 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 11 | key west
# Processing Record 16 of Set 11 | ardakan
# Processing Record 17 of Set 11 | kushmurun
# Processing Record 18 of Set 11 | mahebourg
# Processing Record 19 of Set 11 | gifhorn
# Processing Record 20 of Set 11 | yarmouth
# Processing Record 21 of Set 11 | holland
# Processing Record 22 of Set 11 | algiers
# Processing Record 23 of Set 11 | baykit
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | marsa matruh
# Processing Record 26 of Set 11 | riyadh
# Processing Record 27 of Set 11 | verkhnyaya khava
# Processing Record 28 of Set 11 | daru
# Processing Record 29 of Set 11 | pozo colorado
# Processing Record 30 of Set 11 | kulhudhuffushi
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | teluk nibung
# Processing Record 33 of Set 11 | stornoway
# Processing Record 34 of Set 11 | kyra
# Processing Record 35 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 36 of Set 11 | zyryanka
# Processing Record 37 of Set 11 | balkanabat
# Processing Record 38 of Set 11 | valentin gomez farias
# Processing Record 39 of Set 11 | gat
# Processing Record 40 of Set 11 | tamiahua
# Processing Record 41 of Set 11 | matara
# Processing Record 42 of Set 11 | cedar city
# Processing Record 43 of Set 11 | honningsvag
# Processing Record 44 of Set 11 | syedove
# Processing Record 45 of Set 11 | biltine
# Processing Record 46 of Set 11 | ankang
# Processing Record 47 of Set 11 | horsham
# Processing Record 48 of Set 11 | devecser
# Processing Record 49 of Set 11 | harlingen
# Processing Record 50 of Set 11 | leua
# Processing Record 1 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 2 of Set 12 | wonthaggi
# Processing Record 3 of Set 12 | tura
# Processing Record 4 of Set 12 | londoko
# Processing Record 5 of Set 12 | knysna
# Processing Record 6 of Set 12 | bani walid
# Processing Record 7 of Set 12 | monrovia
# Processing Record 8 of Set 12 | fairbanks
# Processing Record 9 of Set 12 | igreja nova
# Processing Record 10 of Set 12 | sechelt
# Processing Record 11 of Set 12 | fuyang
# Processing Record 12 of Set 12 | sioux lookout
# Processing Record 13 of Set 12 | sistranda
# Processing Record 14 of Set 12 | yatou
# Processing Record 15 of Set 12 | umkomaas
# Processing Record 16 of Set 12 | nokaneng
# Processing Record 17 of Set 12 | mehran
# Processing Record 18 of Set 12 | mizan teferi
# Processing Record 19 of Set 12 | luderitz
# Processing Record 20 of Set 12 | iberia
# Processing Record 21 of Set 12 | bagotville
# Processing Record 22 of Set 12 | abha
# Processing Record 23 of Set 12 | kudahuvadhoo
# Processing Record 24 of Set 12 | haines junction
# Processing Record 25 of Set 12 | gallup
# Processing Record 26 of Set 12 | baykalovo
# Processing Record 27 of Set 12 | jizan
# Processing Record 28 of Set 12 | pauini
# Processing Record 29 of Set 12 | nemuro
# Processing Record 30 of Set 12 | nelidovo
# Processing Record 31 of Set 12 | hamilton
# Processing Record 32 of Set 12 | pustoshka
# Processing Record 33 of Set 12 | dharchula
# Processing Record 34 of Set 12 | santa barbara
# Processing Record 35 of Set 12 | ternate
# Processing Record 36 of Set 12 | havelock
# Processing Record 37 of Set 12 | port lincoln
# Processing Record 38 of Set 12 | north bend
# Processing Record 39 of Set 12 | komsomolskoye
# Processing Record 40 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 12 | leshukonskoye
# Processing Record 42 of Set 12 | amahai
# Processing Record 43 of Set 12 | zeya
# Processing Record 44 of Set 12 | betong
# Processing Record 45 of Set 12 | harper
# Processing Record 46 of Set 12 | am timan
# Processing Record 47 of Set 12 | san juan
# Processing Record 48 of Set 12 | pingdingshan
# Processing Record 49 of Set 12 | bairiki
# Processing Record 50 of Set 12 | inirida
# Processing Record 1 of Set 13 | junction city
# Processing Record 2 of Set 13 | luyang
# Processing Record 3 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 4 of Set 13 | trairi
# Processing Record 5 of Set 13 | union
# Processing Record 6 of Set 13 | katubao
# Processing Record 7 of Set 13 | tilichiki
# Processing Record 8 of Set 13 | macenta
# Processing Record 9 of Set 13 | ongandjera
# Processing Record 10 of Set 13 | tukrah
# Processing Record 11 of Set 13 | cartagena
# Processing Record 12 of Set 13 | puerto escondido
# Processing Record 13 of Set 13 | inta
# Processing Record 14 of Set 13 | mandalgovi
# Processing Record 15 of Set 13 | shakhunya
# Processing Record 16 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 13 | diamantino
# Processing Record 18 of Set 13 | wewak
# Processing Record 19 of Set 13 | marang
# Processing Record 20 of Set 13 | kungurtug
# Processing Record 21 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 13 | nyimba
# Processing Record 23 of Set 13 | yangshan
# Processing Record 24 of Set 13 | sitka
# Processing Record 25 of Set 13 | viradouro
# Processing Record 26 of Set 13 | paka
# Processing Record 27 of Set 13 | suntar
# Processing Record 28 of Set 13 | afrikanda
# Processing Record 29 of Set 13 | glamoc
# Processing Record 30 of Set 13 | haradok
# Processing Record 31 of Set 13 | lovozero
# Processing Record 32 of Set 13 | chegutu
# Processing Record 33 of Set 13 | pestravka
# Processing Record 34 of Set 13 | sambava
# Processing Record 35 of Set 13 | socorro
# Processing Record 36 of Set 13 | turayf
# Processing Record 37 of Set 13 | antofagasta
# Processing Record 38 of Set 13 | narragansett
# Processing Record 39 of Set 13 | kalmunai
# Processing Record 40 of Set 13 | kahama
# Processing Record 41 of Set 13 | jedrzejow
# Processing Record 42 of Set 13 | shediac
# Processing Record 43 of Set 13 | sainte-anne-des-monts
# Processing Record 44 of Set 13 | marapanim
# Processing Record 45 of Set 13 | fukue
# Processing Record 46 of Set 13 | forio
# Processing Record 47 of Set 13 | rosita
# Processing Record 48 of Set 13 | shahr-e babak
# Processing Record 49 of Set 13 | huangchuan
# Processing Record 50 of Set 13 | domoni
# Processing Record 1 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 14 | arrecife
# Processing Record 3 of Set 14 | la ronge
# Processing Record 4 of Set 14 | port arthur
# Processing Record 5 of Set 14 | high prairie
# Processing Record 6 of Set 14 | dong hoi
# Processing Record 7 of Set 14 | shatalovo
# Processing Record 8 of Set 14 | hulyaypole
# Processing Record 9 of Set 14 | bonavista
# Processing Record 10 of Set 14 | elko
# Processing Record 11 of Set 14 | olafsvik
# Processing Record 12 of Set 14 | kurilsk
# Processing Record 13 of Set 14 | asau
# Processing Record 14 of Set 14 | la asuncion
# Processing Record 15 of Set 14 | hokitika
# Processing Record 16 of Set 14 | omboue
# Processing Record 17 of Set 14 | coihaique
# Processing Record 18 of Set 14 | waipawa
# Processing Record 19 of Set 14 | urusha
# Processing Record 20 of Set 14 | sao gabriel
# Processing Record 21 of Set 14 | diego de almagro
# Processing Record 22 of Set 14 | mbanza-ngungu
# Processing Record 23 of Set 14 | raudeberg
# Processing Record 24 of Set 14 | piuma
# Processing Record 25 of Set 14 | bambanglipuro
# Processing Record 26 of Set 14 | kavaratti
# Processing Record 27 of Set 14 | etchojoa
# Processing Record 28 of Set 14 | edd
# Processing Record 29 of Set 14 | ngunguru
# Processing Record 30 of Set 14 | vawkavysk
# Processing Record 31 of Set 14 | krasnovishersk
# Processing Record 32 of Set 14 | muskogee
# Processing Record 33 of Set 14 | whitley bay
# Processing Record 34 of Set 14 | atka
# City not found. Skipping...
# Processing Record 35 of Set 14 | marigot
# Processing Record 36 of Set 14 | karachi
# Processing Record 37 of Set 14 | laurentides
# Processing Record 38 of Set 14 | torrevieja
# Processing Record 39 of Set 14 | kununurra
# Processing Record 40 of Set 14 | aswan
# Processing Record 41 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 14 | san carlos de bariloche
# Processing Record 43 of Set 14 | gobabis
# Processing Record 44 of Set 14 | nizhnyaya tura
# Processing Record 45 of Set 14 | banes
# Processing Record 46 of Set 14 | toamasina
# Processing Record 47 of Set 14 | walvis bay
# Processing Record 48 of Set 14 | trofors
# Processing Record 49 of Set 14 | morant bay
# Processing Record 50 of Set 14 | salinopolis
# Processing Record 1 of Set 15 | ondjiva
# Processing Record 2 of Set 15 | kostomuksha
# Processing Record 3 of Set 15 | houston
# Processing Record 4 of Set 15 | hartselle
# Processing Record 5 of Set 15 | kropotkin
# Processing Record 6 of Set 15 | tessalit
# Processing Record 7 of Set 15 | dunedin
# Processing Record 8 of Set 15 | mantua
# Processing Record 9 of Set 15 | sinnamary
# Processing Record 10 of Set 15 | tyup
# Processing Record 11 of Set 15 | tamasane
# Processing Record 12 of Set 15 | saint-francois
# Processing Record 13 of Set 15 | megion
# Processing Record 14 of Set 15 | bhatkal
# Processing Record 15 of Set 15 | ixtapa
# Processing Record 16 of Set 15 | sherman
# Processing Record 17 of Set 15 | maridi
# Processing Record 18 of Set 15 | coos bay
# Processing Record 19 of Set 15 | silver city
# Processing Record 20 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 15 | goderich
# Processing Record 22 of Set 15 | southbridge
# Processing Record 23 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 15 | talara
# Processing Record 26 of Set 15 | saint-louis
# Processing Record 27 of Set 15 | zabaykalsk
# Processing Record 28 of Set 15 | tucuman
# Processing Record 29 of Set 15 | arandis
# Processing Record 30 of Set 15 | glowno
# Processing Record 31 of Set 15 | bukoba
# Processing Record 32 of Set 15 | chagoda
# Processing Record 33 of Set 15 | gigmoto
# Processing Record 34 of Set 15 | menongue
# Processing Record 35 of Set 15 | cooma
# Processing Record 36 of Set 15 | newport
# Processing Record 37 of Set 15 | san quintin
# Processing Record 38 of Set 15 | half moon bay
# Processing Record 39 of Set 15 | murgab
# Processing Record 40 of Set 15 | alvorada
# Processing Record 41 of Set 15 | auki
# Processing Record 42 of Set 15 | miles city
# Processing Record 43 of Set 15 | angoche
# Processing Record 44 of Set 15 | kibre mengist
# Processing Record 45 of Set 15 | port hawkesbury
# Processing Record 46 of Set 15 | zhanaozen
# Processing Record 47 of Set 15 | rudnogorsk
# Processing Record 48 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 15 | baringo
# Processing Record 50 of Set 15 | beterou
# Processing Record 1 of Set 16 | lima
# Processing Record 2 of Set 16 | ilo
# Processing Record 3 of Set 16 | shenjiamen
# Processing Record 4 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 16 | port-de-bouc
# Processing Record 6 of Set 16 | russell
# Processing Record 7 of Set 16 | gao
# Processing Record 8 of Set 16 | belaya gora
# Processing Record 9 of Set 16 | hermitage
# Processing Record 10 of Set 16 | alice springs
# Processing Record 11 of Set 16 | ondarroa
# Processing Record 12 of Set 16 | horki
# Processing Record 13 of Set 16 | el vigia
# Processing Record 14 of Set 16 | gamba
# Processing Record 15 of Set 16 | yar-sale
# Processing Record 16 of Set 16 | san jeronimo
# Processing Record 17 of Set 16 | anda
# Processing Record 18 of Set 16 | sidi ali
# Processing Record 19 of Set 16 | lubao
# Processing Record 20 of Set 16 | maykain
# City not found. Skipping...
# Processing Record 21 of Set 16 | la grande
# Processing Record 22 of Set 16 | kjollefjord
# Processing Record 23 of Set 16 | capinota
# Processing Record 24 of Set 16 | mogzon
# Processing Record 25 of Set 16 | rawa mazowiecka
# Processing Record 26 of Set 16 | mangochi
# Processing Record 27 of Set 16 | svetlyy
# Processing Record 28 of Set 16 | mecca
# Processing Record 29 of Set 16 | atasu
# Processing Record 30 of Set 16 | can tho
# Processing Record 31 of Set 16 | masunga
# Processing Record 32 of Set 16 | inyonga
# Processing Record 33 of Set 16 | khurba
# Processing Record 34 of Set 16 | tecalitlan
# Processing Record 35 of Set 16 | valparaiso
# Processing Record 36 of Set 16 | ndele
# Processing Record 37 of Set 16 | la rioja
# Processing Record 38 of Set 16 | orlik
# Processing Record 39 of Set 16 | ewa beach
# Processing Record 40 of Set 16 | eganville
# Processing Record 41 of Set 16 | cherepovets
# Processing Record 42 of Set 16 | maraba
# Processing Record 43 of Set 16 | chikoy
# City not found. Skipping...
# Processing Record 44 of Set 16 | kalianget
# Processing Record 45 of Set 16 | gunzenhausen
# Processing Record 46 of Set 16 | mirandopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#create city data dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tiksi      RU  71.6872  128.8694     41.50        74         100
# 1      Georgetown      MY   5.4112  100.3354     84.13        70          20
# 2       Saskylakh      RU  71.9167  114.0833     63.39        52         100
# 3      Vila Velha      BR -20.3297  -40.2925     84.15        61           0
# 4     Krasnogorsk      RU  55.8225   37.3181     87.80        51          40
# ..            ...     ...      ...       ...       ...       ...         ...
# 735   Cherepovets      RU  59.1333   37.9000     82.22        39           0
# 736        Maraba      BR  -5.3686  -49.1178     89.78        62          40
# 737     Kalianget      ID  -7.0500  113.9333     80.91        75          24
# 738  Gunzenhausen      DE  49.1000   10.7500     79.90        54           0
# 739  Mirandopolis      BR -21.1336  -51.1017     67.05        41          99
#
#      Wind Speed              Current Weather
# 0          5.77              overcast clouds
# 1          4.61                   few clouds
# 2          9.01              overcast clouds
# 3         10.36                    clear sky
# 4         11.18  light intensity shower rain
# ..          ...                          ...
# 735       11.18                    clear sky
# 736        5.75             scattered clouds
# 737       12.91                   few clouds
# 738       10.22                    clear sky
# 739       12.33              overcast clouds
#
# [740 rows x 9 columns]

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
